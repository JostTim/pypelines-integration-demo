# %%
from pypelines_integration_demo import pipeline
from one import ONE

# %%
connector = ONE(base_url="http://localhost:80")
# Out:
# Connected to http://localhost:80 as tjostmou

# %%
sessions = connector.search(subject="ea04")#, details = True)
# Out:
# INFO     : search                            : Found 607 sessions. - 2024-11-07 10:21:56

# %%
session = connector.search(id = "ea04/2024-10-04/001")
# Out:
# INFO     : search                            : Found 607 sessions. - 2024-11-07 10:22:37
# INFO     : search                            : Found 607 sessions. - 2024-11-07 10:22:40

# %%
sessions
# Out:
# ['7c229a71-e0ea-4334-9f80-b131c00ad827',
#  '88435a43-41bd-45b5-a658-5bd778a5f099',
#  'f45f19ac-8e00-4f59-8fea-22a9b700bc62',
#  '3795f49c-716f-4e99-b702-2f39678f0e52',
#  '68d46b46-fb25-44cf-b21c-fa16e05c9824',
#  '5f52b2c0-6594-4bd4-b9ea-21d412858754',
#  '4512f3c7-930a-475f-a68e-3024c3a215cc',
#  '4ac87ea1-f8f6-4ac2-b773-fa87fba11ccc',
#  '59cfca73-51fd-43af-a4bb-cd32ac2f0e90',
#  '2aa24163-fc14-47d8-91b4-5fb2d5df9e42',
#  'dd84d249-0f87-452b-a2f9-c558c8a0e07f',
#  '56efa90d-027a-45ae-80ae-13beac6b11ce',
#  '35f053fc-08a0-4c41-a190-839cf8ba3a84',
#  '3e4928f1-fcdf-494e-80a2-36c2d44ccce6',
#  '3bb627f5-da68-487e-8711-c89255976222',
#  'c2389047-496d-4e17-8119-01919589046d',
#  '346944f8-5811-4ee0-b5ec-4b1536202bf3',
#  'f53c0b1b-1cb4-41b5-866a-ad659710741c',
#  '6842758b-b82e-4c32-8458-ae40f77838c2',
#  'b2f008c5-8dd2-425c-819f-aaed09736ee6',
#  '521ffc0f-52e6-4f4c-b541-6981974c4b4e',
#  '80d87f87-670f-4bfb-b9b0-683cd00ad759',
#  '67727125-769e-4da5-8135-34d47058391b',
# ...

# %%
pipeline.process_text.get_virus_check()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pipeline.process_text.get_virus_check()
#
# File c:\Users\Timothe\Documents\python_scripts\pypelines-integration-demo\.venv\Lib\site-packages\pypelines\steps.py:215, in BaseStep.__call__(self, *args, **kwargs)
#     213 def __call__(self, *args, **kwargs):
#     214     """Call the worker method with the given arguments and keyword arguments."""
# --> 215     return loggedmethod(self.worker)(*args, **kwargs)
#
# TypeError: TextPipe.VirusCheckStep.worker() missing 1 required positional argument: 'session'

# %%
pipeline.graph.draw()
# Out:
# <Axes: title={'center': 'Pipeline demo requirement graph'}>
